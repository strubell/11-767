# %%
num_layers = [i for i in range(13)]
memory = [471.576171875, 480.937109375, 505.065625, 537.015625, 562.286328125, 586.283203125, 609.1078125, 640.17890625, 661.06171875, 688.683203125, 701.074609375, 726.834765625, 704.564453125]
inference_time = [0.6762336015701294, 0.652454137802124, 0.5984731912612915, 0.5754918098449707, 0.5094273328781128, 0.4528240203857422, 0.4355964660644531, 0.3862966537475586, 0.3137659549713135, 0.2693749189376831, 0.30468699932098386, 0.207520055770874, 0.11625165939331054]

# %%
num_layers = [i for i in range(13)]
memory = [464.1296875, 485.38046875, 521.92265625, 548.123046875, 582.624609375, 619.799609375, 643.55546875, 671.948828125, 689.91484375, 737.309375, 767.165625, 789.836328125, 732.48046875]
inference_time = [0.6941767454147338, 0.698923659324646, 0.651277494430542, 0.6534608125686645, 0.6385605812072754, 0.6566587209701538, 0.6422648191452026, 0.6646883249282837, 0.7152865886688232, 0.8109283208847046, 0.8032183408737182, 0.8471802711486817, 0.12259995937347412]

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
ax1.plot(num_layers, memory)
ax1.set_title('Memory')
ax1.set_ylabel('Memory (MB)')
ax2.plot(num_layers, inference_time)
ax2.set_title('Inference Time')
ax2.set_ylabel('Time (s)')
# Out:
# Text(0, 0.5, 'Time (s)')
